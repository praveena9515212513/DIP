# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = plt.imread('images.jfif')

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (183, 275, 3)

# %%
R = img[:,:,0]
G = img[:,:,1]
B = img[:,:,2]

# %%
plt.imshow(R)

# %%
plt.gcf().set_size_inches(25,25)
plt.subplot(221),plt.imshow(img),plt.title('Original')
# plt.xticks([]),plt.yticks([])
plt.subplot(222),plt.imshow(R),plt.title('Red')
# plt.xticks([]),plt.yticks([])
plt.subplot(223),plt.imshow(G),plt.title('Green')
# plt.xticks([]),plt.yticks([])
plt.subplot(224),plt.imshow(B),plt.title('Blue')
# plt.xticks([]),plt.yticks([])
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x1ff60eb17f0>,
# ...
#  Text(0.5,1,'Blue'))

# %%
R.shape
# Out:
# (183, 275)

# %%
plt.imshow(G,cmap='gray')

# %%
img1=255-img
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.subplot(122),plt.imshow(img1),plt.title('negative')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x1ff610575c0>,
# ...
#  Text(0.5,1,'negative'))

# %%
im2 = img.copy()
# im2[:,:,0]=255
# im2[:,:,1]=255
im2[:,:,2]=255
plt.imshow(im2)

# %%
im2[0:25,0:25,0]=0
im2[0:25,0:25,1]=255
im2[0:25,0:25,2]=0
plt.imshow(im2)

# %%
imgray = 0.333*R+0.333*G+0.333*B
plt.imshow(imgray)

# %%
imGray = 0.2989*R + 0.5870*G + 0.1140*B
plt.imshow(imGray,cmap='gray')

# %%
import cv2
imGrayCV2 = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-55ebe9c889a3> in <module>()
# ----> 1 import cv2
#       2 imGrayCV2 = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
#
# ModuleNotFoundError: No module named 'cv2'

# %%
pip install cv2
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install cv2
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
conda install opencv
# Out:
#   File "<ipython-input-18-64454965bdaa>", line 1
#     conda install opencv
#                 ^
# SyntaxError: invalid syntax

# %%
img = R*0.7

# %%
plt.imshow(img)
